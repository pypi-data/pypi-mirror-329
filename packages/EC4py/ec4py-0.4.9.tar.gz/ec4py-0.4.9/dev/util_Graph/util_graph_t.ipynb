# %% [markdown]
# # Tafel.
#
# ## 1. Import needed libraries

# %%
from pathlib import Path
import numpy as np
from ec4py.analysis_tafel import Tafel
from ec4py.util_graph import make_plot_1x,plot_options
from ec4py import Quantity_Value_Unit as QV

import matplotlib.pyplot as plt

# %%
make_plot_1x()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 make_plot_1x()
#
# TypeError: make_plot_1x() missing 1 required positional argument: 'Title'

# %%
kwargs =[]
p = plot_options(kwargs)
p.set_x_txt("a","b")
print(p.get_x_txt())
p.exe()
# Out:
# a (b)
# y (y_unit)
# (<matplotlib.lines.Line2D at 0x21b253f8980>,
#  <Axes: xlabel='a (b)', ylabel='y (y_unit)'>)

# %%
kwargs =[]
p = plot_options(kwargs)
p.set_x_txt("$\omega$","${0.5}$")
p.set_y_txt("rpm^{0.5}","aaaa")
print(p.get_x_txt())
a,b = p.exe()
# b.set_ylabel('rpm^0.5 (aaaa)')

#        analyse_plot.set_xlabel("$\omega^{0.5}$ ( rpm$^{0.5}$)")
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# <>:3: SyntaxWarning: invalid escape sequence '\o'
# C:\Users\gusta\AppData\Local\Temp\ipykernel_12940\4209269479.py:3: SyntaxWarning: invalid escape sequence '\o'
#   p.set_x_txt("$\omega$","${0.5}$")
# $\omega$ (${0.5}$)
