# %%
from ec4py import Step_Data

# %%
from dotenv import load_dotenv
import os
from pathlib import Path
load_dotenv()

projectPath = Path(os.getenv("PROJECT_FOLDER"))
print(projectPath)
# Out:
# C:\Users\gusta\Documents\GitHub\NordicEC\EC4py

# %%
data = Step_Data(projectPath /"test_data" / "Step" / "Rotation" / "Steps_125706.tdms")

# %%
data.plot()
# Out:
# (<matplotlib.lines.Line2D at 0x21e935baf90>,
#  <Axes: xlabel='t (s)', ylabel='i (A)'>)

# %%
data[1].plot()
# Out:
# (<matplotlib.lines.Line2D at 0x21e936080e0>,
#  <Axes: xlabel='t (s)', ylabel='i (A)'>)

# %%
print(data.nr_of_steps)
p = None
for x in range(2,data.nr_of_steps):
    line, p=data[x].plot("Time","i", plot=p)
# Out:
# 11

# %%
i_p, i_n = data.get_i_at_E(-0.4)
print(i_p,i_n)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 i_p, i_n = data.get_i_at_E(-0.4)
#       2 print(i_p,i_n)
#
# AttributeError: 'Step_Data' object has no attribute 'get_i_at_E'
